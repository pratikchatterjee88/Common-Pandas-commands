# %%
#https://www.youtube.com/watch?v=vmEHCJofslg

# %%
import pandas as pd
import numpy as np
import matplotlib as plt
# %matplotlib inline
import seaborn as sns

# %%
train_data=pd.read_excel("Data_Train.xlsx")

# %%
train_data.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
# Reading columns
train_data.columns
# Out:
# Index(['Airline', 'Date_of_Journey', 'Source', 'Destination', 'Route',
#        'Dep_Time', 'Arrival_Time', 'Duration', 'Total_Stops',
#        'Additional_Info', 'Price'],
#       dtype='object')

# %%
# reading each columns

train_data["Airline"]
train_data["Airline"][0:5] # using this we can call the numbers of data we can see
# Out:
# 0         IndiGo
# 1      Air India
# 2    Jet Airways
# 3         IndiGo
# 4         IndiGo
# Name: Airline, dtype: object

# %%
#Airline	Date_of_Journey	Source	Destination	Route	Dep_Time	Arrival_Time	Duration	Total_Stops	Additional_Info	Price
#1	Air India	1/05/2019	Kolkata	Banglore	CCU → IXR → BBI → BLR	05:50	13:15	7h 25m	2 stops	No info	7662

# lets say we want to view only the Route  CCU->IXR etc at row 3

train_data.iloc[2,4]  # 1st number indicate the row number and the 2 number indicate the column number
# Out:
# 'DEL → LKO → BOM → COK'

# %%
# lets take the above example a little further

# we want to see all the data at column 4 

#train_data["Route"]

for index, row in train_data.iterrows():
    print(index, row["Route"])
# Out:
# 0 BLR → DEL
# 1 CCU → IXR → BBI → BLR
# 2 DEL → LKO → BOM → COK
# 3 CCU → NAG → BLR
# 4 BLR → NAG → DEL
# 5 CCU → BLR
# 6 BLR → BOM → DEL
# 7 BLR → BOM → DEL
# 8 BLR → BOM → DEL
# 9 DEL → BOM → COK
# 10 DEL → BLR → COK
# 11 CCU → BLR
# 12 MAA → CCU
# 13 CCU → BOM → BLR
# 14 CCU → BLR
# 15 DEL → AMD → BOM → COK
# 16 DEL → PNQ → COK
# 17 DEL → BOM → COK
# 18 DEL → CCU → BOM → COK
# 19 DEL → BOM → COK
# 20 DEL → BOM → COK
# 21 BLR → COK → DEL
# 22 BLR → DEL
# 23 BLR → DEL
# 24 CCU → BOM → BLR
# 25 DEL → IDR → BOM → COK
# 26 DEL → LKO → COK
# 27 DEL → BOM → COK
# 28 BLR → DEL
# 29 MAA → CCU
# 30 MAA → CCU
# 31 CCU → GAU → DEL → BLR
# 32 BLR → DEL
# 33 DEL → NAG → BOM → COK
# 34 DEL → BOM → COK
# 35 DEL → BOM → COK
# 36 CCU → MAA → BLR
# 37 CCU → BLR
# 38 BLR → BOM → DEL
# 39 DEL → BOM → COK
# 40 DEL → HYD → COK
# 41 BLR → BOM → DEL
# 42 DEL → BOM → COK
# 43 BLR → DEL
# 44 DEL → BOM → COK
# 45 BLR → DEL
# 46 BLR → DEL
# 47 MAA → CCU
# 48 CCU → HYD → BLR
# 49 DEL → AMD → BOM → COK
# ...

# %%
# all unique sources
print("The source locations are: ",train_data["Source"].unique())
print("The destination locations are: ",train_data["Destination"].unique())
# Out:
# The source locations are:  ['Banglore' 'Kolkata' 'Delhi' 'Chennai' 'Mumbai']
# The destination locations are:  ['New Delhi' 'Banglore' 'Cochin' 'Kolkata' 'Delhi' 'Hyderabad']

# %%
# LOC

train_data.loc[0:3]
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218

# %%
# we can also see data like this

train_data.loc[(train_data["Airline"]=="IndiGo")& (train_data["Source"]=="Kolkata")]
# Out:
#       Airline Date_of_Journey   Source Destination            Route Dep_Time  \
# 3      IndiGo      12/05/2019  Kolkata    Banglore  CCU → NAG → BLR    18:05
# 11     IndiGo      18/04/2019  Kolkata    Banglore        CCU → BLR    20:20
# 14     IndiGo      24/04/2019  Kolkata    Banglore        CCU → BLR    17:15
# 133    IndiGo      15/06/2019  Kolkata    Banglore        CCU → BLR    20:25
# 188    IndiGo       3/06/2019  Kolkata    Banglore        CCU → BLR    15:30
# ...       ...             ...      ...         ...              ...      ...
# 10574  IndiGo      21/05/2019  Kolkata    Banglore  CCU → HYD → BLR    19:20
# 10620  IndiGo       6/04/2019  Kolkata    Banglore        CCU → BLR    17:15
# 10621  IndiGo      27/06/2019  Kolkata    Banglore        CCU → BLR    22:15
# 10649  IndiGo       1/03/2019  Kolkata    Banglore        CCU → BLR    21:25
# 10665  IndiGo      27/04/2019  Kolkata    Banglore        CCU → BLR    15:15
#
# ...

# %%
# without even using loc we can get the same output

train_data[(train_data["Airline"]=="IndiGo")& (train_data["Source"]=="Kolkata")]
# Out:
#       Airline Date_of_Journey   Source Destination            Route Dep_Time  \
# 3      IndiGo      12/05/2019  Kolkata    Banglore  CCU → NAG → BLR    18:05
# 11     IndiGo      18/04/2019  Kolkata    Banglore        CCU → BLR    20:20
# 14     IndiGo      24/04/2019  Kolkata    Banglore        CCU → BLR    17:15
# 133    IndiGo      15/06/2019  Kolkata    Banglore        CCU → BLR    20:25
# 188    IndiGo       3/06/2019  Kolkata    Banglore        CCU → BLR    15:30
# ...       ...             ...      ...         ...              ...      ...
# 10574  IndiGo      21/05/2019  Kolkata    Banglore  CCU → HYD → BLR    19:20
# 10620  IndiGo       6/04/2019  Kolkata    Banglore        CCU → BLR    17:15
# 10621  IndiGo      27/06/2019  Kolkata    Banglore        CCU → BLR    22:15
# 10649  IndiGo       1/03/2019  Kolkata    Banglore        CCU → BLR    21:25
# 10665  IndiGo      27/04/2019  Kolkata    Banglore        CCU → BLR    15:15
#
# ...

# %%
# to describe the data

train_data.describe() #this will only show numerical data, since in our dataset we only have numerical coulumn as "price"
# Out:
#               Price
# count  10683.000000
# mean    9087.064121
# std     4611.359167
# min     1759.000000
# 25%     5277.000000
# 50%     8372.000000
# 75%    12373.000000
# max    79512.000000

# %%
# sorting the dataset

train_data.sort_values("Price", ascending=False)  # we are sorting data based on Price, ascending =  True/ False are self explt.
# Out:
#                     Airline Date_of_Journey    Source Destination  \
# 2924   Jet Airways Business      01/03/2019  Banglore   New Delhi
# 5372   Jet Airways Business      01/03/2019  Banglore   New Delhi
# 10364  Jet Airways Business      01/03/2019  Banglore   New Delhi
# 1478            Jet Airways      18/03/2019  Banglore   New Delhi
# 5439            Jet Airways      01/03/2019  Banglore   New Delhi
# ...                     ...             ...       ...         ...
# 1513            Jet Airways      27/03/2019    Mumbai   Hyderabad
# 10513              SpiceJet      27/03/2019    Mumbai   Hyderabad
# 4839               SpiceJet       3/04/2019    Mumbai   Hyderabad
# 4066               SpiceJet      21/03/2019    Mumbai   Hyderabad
# 4274               SpiceJet      27/03/2019    Mumbai   Hyderabad
#
#                  Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 2924   BLR → BOM → DEL    05:45         11:25   5h 40m      1 stop
# ...

# %%
# We can also use multiple criteria for sorting

train_data.sort_values(["Price","Source"], ascending=[0,1]) # ascending 0== descending[Price] and 1==ascending[Source]
# Out:
#                     Airline Date_of_Journey    Source Destination  \
# 2924   Jet Airways Business      01/03/2019  Banglore   New Delhi
# 5372   Jet Airways Business      01/03/2019  Banglore   New Delhi
# 10364  Jet Airways Business      01/03/2019  Banglore   New Delhi
# 1478            Jet Airways      18/03/2019  Banglore   New Delhi
# 2618            Jet Airways      18/03/2019  Banglore   New Delhi
# ...                     ...             ...       ...         ...
# 1513            Jet Airways      27/03/2019    Mumbai   Hyderabad
# 4066               SpiceJet      21/03/2019    Mumbai   Hyderabad
# 4274               SpiceJet      27/03/2019    Mumbai   Hyderabad
# 4839               SpiceJet       3/04/2019    Mumbai   Hyderabad
# 10513              SpiceJet      27/03/2019    Mumbai   Hyderabad
#
#                  Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 2924   BLR → BOM → DEL    05:45         11:25   5h 40m      1 stop
# ...

# %%
train_data.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302

# %%
# To convert a column. Here price was in str format and we converted it to integer

train_data['Price']= train_data['Price'].astype(int)

# %%
train_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10683 entries, 0 to 10682
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Airline          10683 non-null  object
#  1   Date_of_Journey  10683 non-null  object
#  2   Source           10683 non-null  object
#  3   Destination      10683 non-null  object
#  4   Route            10682 non-null  object
#  5   Dep_Time         10683 non-null  object
#  6   Arrival_Time     10683 non-null  object
#  7   Duration         10683 non-null  object
#  8   Total_Stops      10682 non-null  object
#  9   Additional_Info  10683 non-null  object
#  10  Price            10683 non-null  int32
# dtypes: int32(1), object(10)
# memory usage: 876.5+ KB

# %%
# creating a new column with new price 50% less than the current

train_data['half price']=train_data['Price']*50/100

# %%
train_data.head()
# Out:
#        Airline Date_of_Journey    Source Destination                  Route  \
# 0       IndiGo      24/03/2019  Banglore   New Delhi              BLR → DEL
# 1    Air India       1/05/2019   Kolkata    Banglore  CCU → IXR → BBI → BLR
# 2  Jet Airways       9/06/2019     Delhi      Cochin  DEL → LKO → BOM → COK
# 3       IndiGo      12/05/2019   Kolkata    Banglore        CCU → NAG → BLR
# 4       IndiGo      01/03/2019  Banglore   New Delhi        BLR → NAG → DEL
#
#   Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price  \
# 0    22:20  01:10 22 Mar   2h 50m    non-stop         No info   3897
# 1    05:50         13:15   7h 25m     2 stops         No info   7662
# 2    09:25  04:25 10 Jun      19h     2 stops         No info  13882
# 3    18:05         23:30   5h 25m      1 stop         No info   6218
# 4    16:50         21:35   4h 45m      1 stop         No info  13302
#
#    half price
# 0      1948.5
# 1      3831.0
# 2      6941.0
# 3      3109.0
# 4      6651.0

# %% [markdown]
# #### Saving data

# %%
# train_data.to_csv("Modified.csv")
#train_data.to_excel("Modified.xlsx")
#train_data.to_csv("Modified.txt", sep='\t')

# %% [markdown]
# #### Filtering data

# %%
#viewing only airlines from Kolkata and price<5000

train_data[(train_data["Source"]=="Kolkata") & (train_data["Price"]<5000)]
# Out:
#          Airline Date_of_Journey   Source Destination            Route  \
# 5       SpiceJet      24/06/2019  Kolkata    Banglore        CCU → BLR
# 11        IndiGo      18/04/2019  Kolkata    Banglore        CCU → BLR
# 14        IndiGo      24/04/2019  Kolkata    Banglore        CCU → BLR
# 36      SpiceJet      21/05/2019  Kolkata    Banglore  CCU → MAA → BLR
# 94     Air India      21/04/2019  Kolkata    Banglore        CCU → BLR
# ...          ...             ...      ...         ...              ...
# 10621     IndiGo      27/06/2019  Kolkata    Banglore        CCU → BLR
# 10649     IndiGo       1/03/2019  Kolkata    Banglore        CCU → BLR
# 10665     IndiGo      27/04/2019  Kolkata    Banglore        CCU → BLR
# 10678   Air Asia       9/04/2019  Kolkata    Banglore        CCU → BLR
# 10679  Air India      27/04/2019  Kolkata    Banglore        CCU → BLR
#
#       Dep_Time  Arrival_Time Duration Total_Stops Additional_Info  Price  \
# ...

# %%
# another filtering using text search

train_data[train_data["Airline"].str.contains("Business")]
# Out:
#                     Airline Date_of_Journey    Source Destination  \
# 657    Jet Airways Business      01/03/2019  Banglore   New Delhi
# 2924   Jet Airways Business      01/03/2019  Banglore   New Delhi
# 5372   Jet Airways Business      01/03/2019  Banglore   New Delhi
# 7351   Jet Airways Business       3/03/2019     Delhi      Cochin
# 9715   Jet Airways Business       6/03/2019     Delhi      Cochin
# 10364  Jet Airways Business      01/03/2019  Banglore   New Delhi
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 657          BLR → BOM → DEL    05:45         10:45       5h      1 stop
# 2924         BLR → BOM → DEL    05:45         11:25   5h 40m      1 stop
# 5372         BLR → BOM → DEL    05:45         12:25   6h 40m      1 stop
# 7351   DEL → ATQ → BOM → COK    20:05  04:25 04 Mar   8h 20m     2 stops
# 9715   DEL → ATQ → BOM → COK    20:05  04:25 07 Mar   8h 20m     2 stops
# ...

# %%
train_data[(train_data["Airline"].str.contains("Air|Go"))]
# Out:
#            Airline Date_of_Journey    Source Destination  \
# 0           IndiGo      24/03/2019  Banglore   New Delhi
# 1        Air India       1/05/2019   Kolkata    Banglore
# 2      Jet Airways       9/06/2019     Delhi      Cochin
# 3           IndiGo      12/05/2019   Kolkata    Banglore
# 4           IndiGo      01/03/2019  Banglore   New Delhi
# ...            ...             ...       ...         ...
# 10675    Air India       9/06/2019    Mumbai   Hyderabad
# 10678     Air Asia       9/04/2019   Kolkata    Banglore
# 10679    Air India      27/04/2019   Kolkata    Banglore
# 10680  Jet Airways      27/04/2019  Banglore       Delhi
# 10682    Air India       9/05/2019     Delhi      Cochin
#
#                        Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0                  BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1      CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# ...

# %% [markdown]
# ### Groupby

# %%
# lets say we want to see average price for airlines

train_data.groupby(by="Airline" ).mean()
# Out:
#                                           Price    half price
# Airline
# Air Asia                            5590.260188   2795.130094
# Air India                           9611.210616   4805.605308
# GoAir                               5861.056701   2930.528351
# IndiGo                              5673.682903   2836.841452
# Jet Airways                        11643.923357   5821.961678
# Jet Airways Business               58358.666667  29179.333333
# Multiple carriers                  10902.678094   5451.339047
# Multiple carriers Premium economy  11418.846154   5709.423077
# SpiceJet                            4338.284841   2169.142421
# Trujet                              4140.000000   2070.000000
# Vistara                             7796.348643   3898.174322
# Vistara Premium economy             8962.333333   4481.166667

# %%
train_data.groupby('Airline').mean().sort_values('Price', ascending=False)
# Out:
#                                           Price    half price
# Airline
# Jet Airways Business               58358.666667  29179.333333
# Jet Airways                        11643.923357   5821.961678
# Multiple carriers Premium economy  11418.846154   5709.423077
# Multiple carriers                  10902.678094   5451.339047
# Air India                           9611.210616   4805.605308
# Vistara Premium economy             8962.333333   4481.166667
# Vistara                             7796.348643   3898.174322
# GoAir                               5861.056701   2930.528351
# IndiGo                              5673.682903   2836.841452
# Air Asia                            5590.260188   2795.130094
# SpiceJet                            4338.284841   2169.142421
# Trujet                              4140.000000   2070.000000

# %%
groupby=train_data.groupby(['Airline','Source']).agg({'Destination':'count'})
groupby
# Out:
#                                             Destination
# Airline                           Source
# Air Asia                          Banglore           89
#                                   Delhi              80
#                                   Kolkata           150
# Air India                         Banglore          332
#                                   Chennai            25
#                                   Delhi             747
#                                   Kolkata           512
#                                   Mumbai            136
# GoAir                             Banglore           93
#                                   Delhi              76
#                                   Kolkata            25
# IndiGo                            Banglore          523
#                                   Chennai           184
#                                   Delhi             705
#                                   Kolkata           445
# ...

# %%
train_data.unstack(0)
# Out:
# Airline     0             IndiGo
#             1          Air India
#             2        Jet Airways
#             3             IndiGo
#             4             IndiGo
#                         ...
# half price  10678         2053.5
#             10679         2072.5
#             10680         3614.5
#             10681           6324
#             10682         5876.5
# Length: 128196, dtype: object

# %% [markdown]
# #### Melting

# %%
train_data.melt(id_vars=['Airline', 'Source'], value_vars='Price')
# Out:
#            Airline    Source variable  value
# 0           IndiGo  Banglore    Price   3897
# 1        Air India   Kolkata    Price   7662
# 2      Jet Airways     Delhi    Price  13882
# 3           IndiGo   Kolkata    Price   6218
# 4           IndiGo  Banglore    Price  13302
# ...            ...       ...      ...    ...
# 10678     Air Asia   Kolkata    Price   4107
# 10679    Air India   Kolkata    Price   4145
# 10680  Jet Airways  Banglore    Price   7229
# 10681      Vistara  Banglore    Price  12648
# 10682    Air India     Delhi    Price  11753
#
# [10683 rows x 4 columns]

# %% [markdown]
# #### Pivot Table

# %%
train_data.pivot_table(values='Price',index=['Airline','Source'], columns=['Destination'])
# Out:
# Destination                                     Banglore        Cochin  \
# Airline                           Source
# Air Asia                          Banglore           NaN           NaN
#                                   Delhi              NaN   7804.175000
#                                   Kolkata    5012.320000           NaN
# Air India                         Banglore           NaN           NaN
#                                   Chennai            NaN           NaN
#                                   Delhi              NaN  10000.068273
#                                   Kolkata   10357.324219           NaN
#                                   Mumbai             NaN           NaN
# GoAir                             Banglore           NaN           NaN
#                                   Delhi              NaN   6587.157895
#                                   Kolkata    7047.000000           NaN
# IndiGo                            Banglore           NaN           NaN
# ...

# %%
pd.pivot_table(train_data,values='Price',index=['Source','Destination'],columns=['Airline'])
# Out:
# Airline                  Air Asia     Air India        GoAir       IndiGo  \
# Source   Destination
# Banglore Delhi        4265.577465   6045.166667  4050.289855  4399.581967
#          New Delhi    5791.944444  11045.575472  7532.333333  7312.828025
# Chennai  Kolkata              NaN   5895.640000          NaN  4538.766304
# Delhi    Cochin       7804.175000  10000.068273  6587.157895  7203.933333
# Kolkata  Banglore     5012.320000  10357.324219  7047.000000  5075.235955
# Mumbai   Hyderabad            NaN   6260.051471          NaN  3659.816327
#
# Airline                Jet Airways  Jet Airways Business  Multiple carriers  \
# Source   Destination
# Banglore Delhi         6412.954054                   NaN                NaN
#          New Delhi    15101.272727              62844.25                NaN
# Chennai  Kolkata               NaN                   NaN                NaN
# Delhi    Cochin       12642.593317              49387.50       10902.678094
# ...

# %%
# lets say we have a huge size of data then to read the complete file it will take lot of time
# we can use chunk size inside a function to read our data.

for df in pd.read_csv("Modified.csv", chunksize=6):
    print("Chunk_df")
    print(df)
# Out:
# Chunk_df
#    Unnamed: 0      Airline Date_of_Journey    Source Destination  \
# 0           0       IndiGo      24/03/2019  Banglore   New Delhi
# 1           1    Air India       1/05/2019   Kolkata    Banglore
# 2           2  Jet Airways       9/06/2019     Delhi      Cochin
# 3           3       IndiGo      12/05/2019   Kolkata    Banglore
# 4           4       IndiGo      01/03/2019  Banglore   New Delhi
# 5           5     SpiceJet      24/06/2019   Kolkata    Banglore
#
#                    Route Dep_Time  Arrival_Time Duration Total_Stops  \
# 0              BLR → DEL    22:20  01:10 22 Mar   2h 50m    non-stop
# 1  CCU → IXR → BBI → BLR    05:50         13:15   7h 25m     2 stops
# 2  DEL → LKO → BOM → COK    09:25  04:25 10 Jun      19h     2 stops
# 3        CCU → NAG → BLR    18:05         23:30   5h 25m      1 stop
# 4        BLR → NAG → DEL    16:50         21:35   4h 45m      1 stop
# 5              CCU → BLR    09:00         11:25   2h 25m    non-stop
#
# ...
